# %%
from urllib.parse import urlparse
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/newURL/'
# %run {file_path}url_feature_parse.py

# %%
df = pd.read_csv('/content/drive/MyDrive/newURL/kaggle.csv')

# %%
df
# Out:
#         label                                                URL  url_length  \
# 0           0                mp3raid.com/music/krizz_kaliko.html          35
# 1           0                    bopsecrets.org/rexroth/cr/1.htm          31
# 2           0  http://buzzfil.net/m/show-art/ils-etaient-loin...         118
# 3           0      espn.go.com/nba/player/_/id/3457/brandon-rush          45
# 4           0     yourbittorrent.com/?q=anthony-hamilton-soulife          46
# ...       ...                                                ...         ...
# 522209      1            xbox360.ign.com/objects/850/850402.html          39
# 522210      1       games.teamxbox.com/xbox-360/1860/Dead-Space/          44
# 522211      1         www.gamespot.com/xbox360/action/deadspace/          42
# 522212      1      en.wikipedia.org/wiki/Dead_Space_(video_game)          45
# 522213      1          www.angelfire.com/goth/devilmaycrytonite/          41
#
# ...

# %%
url_col = 'URL'
new_df = combined_url_features(df,url_col)

# %%
new_df
# Out:
#                                                       URL  label  url_length  \
# 0       http://1337x.to/torrent/1110018/Blackhat-2015-...      0          83
# 1       http://1337x.to/torrent/1122940/Blackhat-2015-...      0          83
# 2       http://1337x.to/torrent/1124395/Fast-and-Furio...      0          83
# 3       http://1337x.to/torrent/1145504/Avengers-Age-o...      0          83
# 4       http://1337x.to/torrent/1160078/Avengers-age-o...      0          83
# ...                                                   ...    ...         ...
# 165356  http://www.laurenzano.com.ar/index.php?option=...      1          87
# 165357  http://www.laurenzano.com.ar/templates/laurenz...      1          69
# 165358  http://www.laurenzano.com.ar/templates/laurenz...      1          72
# 165359                 http://www.laurenzano.com.ar/x.txt      1          34
# 165360          http://www.emotionalassets.com/sejeal.jpg      1          41
#
# ...

# %%
output_csv_file_path = '/content/drive/MyDrive/newURL/iscx-2016.csv'
new_df.to_csv(output_csv_file_path, index=False)
