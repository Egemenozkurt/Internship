# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# cheng
df = pd.read_csv("/content/drive/MyDrive/newURL/spam_dataset.csv")
header_list = ['URL']

# chenge here
output_csv_file_path = '/content/drive/MyDrive/newURL/new_spam.csv'
df.to_csv(output_csv_file_path, header=header_list, index=False)

# %%
# chenge here as well
new_df = pd.read_csv("/content/drive/MyDrive/newURL/new_spam.csv")

# adjust label value accordingly
new_df['label'] = 1
new_df.to_csv(output_csv_file_path, index=False)

# %%
df1 = pd.read_csv("/content/drive/MyDrive/newURL/new_benign.csv")
df2= pd.read_csv("/content/drive/MyDrive/newURL/new_phishing.csv")
df3 = pd.read_csv("/content/drive/MyDrive/newURL/new_malware.csv")
df4 = pd.read_csv("/content/drive/MyDrive/newURL/new_spam.csv")
df5 = pd.read_csv("/content/drive/MyDrive/newURL/new_defacement.csv")
# Out:
# Total row count: 25

# %%
data_frames = [df1, df2, df3, df4, df5]
total_row_count = 0
for df in data_frames:
    total_row_count += len(df)

# %%
total_row_count
# Out:
# 165361

# %%
merged_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

merged_csv_file_path = '/content/drive/MyDrive/newURL/merged_data.csv'

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(merged_csv_file_path, index=False)

# %%
merged_df
