# %%
from urllib.parse import urlparse
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/WHOIS/test_Whois-HTML.csv')

# %%
df
# Out:
#                                                     URL  \
# 0           http://offshore.serviceboaway.com/login.php
# 1                        https://gwd.tta.mybluehost.me/
# 2     https://steamcommnrurtiy.com/profiles/76562606...
# 3                                   http://royalm.info/
# 4                                  https://urlz.fr/mWVR
# ...                                                 ...
# 3995                                https://krosmoz.com
# 3996                                   https://en25.com
# 3997                                  https://d-nb.info
# 3998                                  https://reired.ru
# 3999                                https://jumia.co.tz
#
#                                            HTML_Content  \
# 0     <!doctype html>\r\n<html class="no-js" lang="e...
# 1                                                   NaN
# 2     <!DOCTYPE html>\n<html>\n\n<head>\n    <meta c...
# 3     <!DOCTYPE html>\r\n<html>\r\n<head>\r\n \r\n<m...
# 4      \n<html lang="fr" class=" backgroundblendmode...
# ...                                                 ...
# 3995                                                NaN
# 3996                                                NaN
# 3997  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 3998                                                NaN
# 3999  <!DOCTYPE html>\n<!--[if lt IE 7]> <html class...
#
#                                                   Whois  label
# 0     {\n  "domain_name": "SERVICEBOAWAY.COM",\n  "r...      1
# 1     {\n  "domain_id": "D425500000000848216-AGRS",\...      1
# 2     {\n  "domain_name": "STEAMCOMMNRURTIY.COM",\n ...      1
# 3     {\n  "domain_name": "royalm.info",\n  "registr...      1
# 4     {\n  "domain_name": "urlz.fr",\n  "registrar":...      1
# ...                                                 ...    ...
# 3995                                                NaN      0
# 3996  {\n  "domain_name": "EN25.COM",\n  "registrar"...      0
# 3997  {\n  "domain_name": "d-nb.info",\n  "registrar...      0
# 3998  {\n  "domain_name": "REIRED.RU",\n  "registrar...      0
# 3999                                                NaN      0
#
# [4000 rows x 4 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                                     URL  \
# 0           http://offshore.serviceboaway.com/login.php
# 1     https://steamcommnrurtiy.com/profiles/76562606...
# 2                                   http://royalm.info/
# 3                                  https://urlz.fr/mWVR
# 4     https://service-GSt3BTbqP2.escalated.com.au/#a...
# ...                                                 ...
# 1958                               https://ageuk.org.uk
# 1959                                   https://drmax.cz
# 1960                             https://pioneer-car.eu
# 1961                                  https://hrr.co.uk
# 1962                                  https://d-nb.info
#
#                                            HTML_Content  \
# 0     <!doctype html>\r\n<html class="no-js" lang="e...
# 1     <!DOCTYPE html>\n<html>\n\n<head>\n    <meta c...
# 2     <!DOCTYPE html>\r\n<html>\r\n<head>\r\n \r\n<m...
# 3      \n<html lang="fr" class=" backgroundblendmode...
# 4     <script language=javascript>var _0x416ac3=_0xb...
# ...                                                 ...
# 1958  ﻿\n\n\n<!DOCTYPE html>\n<!--[if IE 9 ]> <html ...
# 1959  <!doctype html>\n<html data-n-head-ssr lang="e...
# 1960  <!DOCTYPE html>\n<html  prefix="og: http://ogp...
# 1961  <!DOCTYPE html>\n<html lang="en-GB">\n<head>\n...
# 1962  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
#
#                                                   Whois  label
# 0     {\n  "domain_name": "SERVICEBOAWAY.COM",\n  "r...      1
# 1     {\n  "domain_name": "STEAMCOMMNRURTIY.COM",\n ...      1
# 2     {\n  "domain_name": "royalm.info",\n  "registr...      1
# 3     {\n  "domain_name": "urlz.fr",\n  "registrar":...      1
# 4     {\n  "domain_name": "ESCALATED.COM.AU",\n  "up...      1
# ...                                                 ...    ...
# 1958  {\n  "domain_name": "ageuk.org.uk",\n  "regist...      0
# 1959  {\n  "domain_name": "drmax.cz",\n  "registrant...      0
# 1960  {\n  "domain_name": "pioneer-car.eu",\n  "tech...      0
# 1961  {\n  "domain_name": "hrr.co.uk",\n  "registrar...      0
# 1962  {\n  "domain_name": "d-nb.info",\n  "registrar...      0
#
# [1963 rows x 4 columns]

# %%
df.label.value_counts()
# Out:
# 1    1165
# 0     798
# Name: label, dtype: int64

# %%
output_csv_file_path = '/content/drive/MyDrive/WHOIS/2000_test_Whois-HTML.csv'
df.to_csv(output_csv_file_path, index=False)
