# %%
from urllib.parse import urlparse
import re
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/merge_and_URLTraditional_iscx_2016/'
# %run {file_path}url_feature_parse.py

# %%
df = pd.read_csv('/content/drive/MyDrive/parse_kaggle/malicious_phish.csv')

# %%
df
# Out:
#                                                       url        type
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
# [651191 rows x 2 columns]

# %%
url_col = 'url'
new_df = combined_url_features(df,url_col)

# %%
new_df
# Out:
#                                                       url        type  \
# 0                                        br-icloud.com.br    phishing
# 1                     mp3raid.com/music/krizz_kaliko.html      benign
# 2                         bopsecrets.org/rexroth/cr/1.htm      benign
# 3       http://www.garage-pirenne.be/index.php?option=...  defacement
# 4       http://adventure-nicaragua.net/index.php?optio...  defacement
# ...                                                   ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html    phishing
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/    phishing
# 651188         www.gamespot.com/xbox360/action/deadspace/    phishing
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)    phishing
# 651190          www.angelfire.com/goth/devilmaycrytonite/    phishing
#
#         url_length  hostname_count  subdomain_count  special_character_count  \
# ...

# %%
new_df = new_df.drop(columns = 'new_URL')

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

new_df['label']= label_encoder.fit_transform(new_df['type'])

# %%
new_df = new_df.drop(columns = 'type')

# %%
first_column = new_df.pop('label')
new_df.insert(1, 'label', first_column)

# %%
new_df = pd.read_csv('/content/drive/MyDrive/parse_kaggle/parsed_kaggle.csv')

# %%
new_df
# Out:
#                                                       url  label  url_length  \
# 0                                        br-icloud.com.br      3          16
# 1                     mp3raid.com/music/krizz_kaliko.html      0          35
# 2                         bopsecrets.org/rexroth/cr/1.htm      0          31
# 3       http://www.garage-pirenne.be/index.php?option=...      1          88
# 4       http://adventure-nicaragua.net/index.php?optio...      1         235
# ...                                                   ...    ...         ...
# 651186            xbox360.ign.com/objects/850/850402.html      3          39
# 651187       games.teamxbox.com/xbox-360/1860/Dead-Space/      3          44
# 651188         www.gamespot.com/xbox360/action/deadspace/      3          42
# 651189      en.wikipedia.org/wiki/Dead_Space_(video_game)      3          45
# 651190          www.angelfire.com/goth/devilmaycrytonite/      3          41
#
# ...

# %%
new_df =new_df.rename(columns = {'url':'URL'})

# %%
new_df['label'] = new_df['label'].replace([2, 3], 1)

# %%
new_df['label'].value_counts()
# Out:
# 0    428103
# 1    223088
# Name: label, dtype: int64

# %%
output_csv_file_path = '/content/drive/MyDrive/parse_kaggle/0_and_1_parsed_kaggle.csv'
new_df.to_csv(output_csv_file_path, index=False)
