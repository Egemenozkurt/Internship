# %%
import pandas as pd
import os

# %%
df = pd.read_csv('1tabularalexa.csv')
column_name = 'Screenshot_ID'
csv_column_names = df[column_name].tolist()
csv_column_names.sort()

# %%
file = 'notchanged_alexa'
png_files =os.listdir(file)
png_file_names = [file_name.replace('.png', '') for file_name in png_files]
png_file_names.sort()

# %%
csv_column_names
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  7,
#  8,
#  10,
#  12,
#  14,
#  15,
#  17,
#  19,
#  20,
#  26,
#  30,
#  34,
#  35,
#  37,
#  38,
#  39,
#  45,
#  49,
#  51,
#  53,
#  54,
#  56,
#  60,
#  64,
#  66,
#  68,
#  69,
#  70,
#  74,
#  76,
#  77,
#  81,
#  82,
#  85,
#  91,
#  92,
#  94,
#  95,
#  106,
#  108,
#  109,
#  110,
#  111,
#  113,
#  117,
#  119,
#  122,
#  123,
#  126,
#  128,
#  129,
#  130,
#  131,
#  132,
#  136,
#  137,
#  138,
#  142,
#  144,
#  147,
#  150,
#  152,
#  154,
#  157,
#  158,
#  159,
#  161,
#  162,
#  166,
#  168,
#  170,
#  172,
#  174,
#  175,
#  178,
#  180,
#  181,
#  184,
#  186,
#  188,
#  189,
#  194,
#  195,
#  197,
#  198,
#  199,
#  201,
#  206,
#  217,
#  219,
#  226,
#  228,
#  235,
#  236,
#  243,
#  245,
#  248,
#  249,
#  250,
#  254,
#  256,
#  258,
#  259,
#  260,
#  265,
#  267,
#  271,
#  272,
#  273,
#  275,
#  282,
#  285,
#  286,
#  287,
#  290,
#  295,
#  297,
#  298,
#  301,
#  303,
#  304,
#  307,
#  311,
#  315,
#  317,
# ...

# %%
png_file_names
# Out:
# ['0',
#  '1',
#  '10',
#  '1000',
#  '1001',
#  '1002',
#  '1005',
#  '1008',
#  '1012',
#  '1019',
#  '1022',
#  '1024',
#  '1028',
#  '1031',
#  '1033',
#  '1036',
#  '1041',
#  '1044',
#  '1045',
#  '1051',
#  '1055',
#  '1058',
#  '106',
#  '108',
#  '109',
#  '110',
#  '111',
#  '113',
#  '117',
#  '119',
#  '12',
#  '122',
#  '123',
#  '126',
#  '128',
#  '129',
#  '130',
#  '131',
#  '132',
#  '136',
#  '137',
#  '138',
#  '14',
#  '142',
#  '144',
#  '147',
#  '15',
#  '150',
#  '152',
#  '154',
#  '157',
#  '158',
#  '159',
#  '161',
#  '162',
#  '166',
#  '168',
#  '17',
#  '170',
#  '172',
#  '174',
#  '175',
#  '178',
#  '180',
#  '181',
#  '184',
#  '186',
#  '188',
#  '189',
#  '19',
#  '194',
#  '195',
#  '197',
#  '198',
#  '199',
#  '2',
#  '20',
#  '201',
#  '206',
#  '217',
#  '219',
#  '226',
#  '228',
#  '235',
#  '236',
#  '243',
#  '245',
#  '248',
#  '249',
#  '250',
#  '254',
#  '256',
#  '258',
#  '259',
#  '26',
#  '260',
#  '265',
#  '267',
#  '271',
# ...

# %%
third = [item for item in csv_column_names if item not in png_file_names]

# %%
third
# Out:
# [0,
#  1,
#  2,
#  3,
#  4,
#  5,
#  7,
#  8,
#  10,
#  12,
#  14,
#  15,
#  17,
#  19,
#  20,
#  26,
#  30,
#  34,
#  35,
#  37,
#  38,
#  39,
#  45,
#  49,
#  51,
#  53,
#  54,
#  56,
#  60,
#  64,
#  66,
#  68,
#  69,
#  70,
#  74,
#  76,
#  77,
#  81,
#  82,
#  85,
#  91,
#  92,
#  94,
#  95,
#  106,
#  108,
#  109,
#  110,
#  111,
#  113,
#  117,
#  119,
#  122,
#  123,
#  126,
#  128,
#  129,
#  130,
#  131,
#  132,
#  136,
#  137,
#  138,
#  142,
#  144,
#  147,
#  150,
#  152,
#  154,
#  157,
#  158,
#  159,
#  161,
#  162,
#  166,
#  168,
#  170,
#  172,
#  174,
#  175,
#  178,
#  180,
#  181,
#  184,
#  186,
#  188,
#  189,
#  194,
#  195,
#  197,
#  198,
#  199,
#  201,
#  206,
#  217,
#  219,
#  226,
#  228,
#  235,
#  236,
#  243,
#  245,
#  248,
#  249,
#  250,
#  254,
#  256,
#  258,
#  259,
#  260,
#  265,
#  267,
#  271,
#  272,
#  273,
#  275,
#  282,
#  285,
#  286,
#  287,
#  290,
#  295,
#  297,
#  298,
#  301,
#  303,
#  304,
#  307,
#  311,
#  315,
#  317,
# ...
